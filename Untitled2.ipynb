# %%
from pyecharts import Bar

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图数据堆叠示例")
bar.add("商家A", attr, v1, is_stack=True)
bar.add("商家B", attr, v2, is_stack=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9d2b19d12443492695b1abbb6080c343" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9d2b19d12443492695b1abbb6080c343 = echarts.init(document.getElementById('9d2b19d12443492695b1abbb6080c343'), 'light', {renderer: 'canvas'});
#
# var option_9d2b19d12443492695b1abbb6080c343 = {
#     "toolbox": {
#         "top": "center",
#         "feature": {
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "left": "95%"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "type": "category",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "title": [
#         {
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "series": [
#         {
#             "name": "\u5546\u5bb6A",
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1287694,
#             "stack": "stack_1287694",
#             "type": "bar",
#             "barCategoryGap": "20%",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "name": "\u5546\u5bb6B",
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1287694,
#             "stack": "stack_1287694",
#             "type": "bar",
#             "barCategoryGap": "20%",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "legend": [
#         {
#             "top": "top",
#             "show": true,
#             "selectedMode": "multiple",
#             "left": "center",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "type": "value",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series_id": 1287694
# };
# myChart_9d2b19d12443492695b1abbb6080c343.setOption(option_9d2b19d12443492695b1abbb6080c343);
#
#     });
# </script>

# %%
bar = Bar("标记线和标记点示例")
bar.add("商家A", attr, v1, mark_point=["average"])
bar.add("商家B", attr, v2, mark_line=["min", "max"])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d084813a53c64bdaa95f3573bdb48d55" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d084813a53c64bdaa95f3573bdb48d55 = echarts.init(document.getElementById('d084813a53c64bdaa95f3573bdb48d55'), 'light', {renderer: 'canvas'});
#
# var option_d084813a53c64bdaa95f3573bdb48d55 = {
#     "title": [
#         {
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u6807\u8bb0\u7ebf\u548c\u6807\u8bb0\u70b9\u793a\u4f8b",
#             "top": "auto"
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": true
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "type": "value",
#             "axisLabel": {
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "margin": 8
#             },
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "seriesId": 8586725,
#             "markPoint": {
#                 "data": [
#                     {
#                         "name": "mean-Value",
#                         "type": "average",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "type": "bar",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markLine": {
#                 "data": []
#             }
#         },
#         {
#             "barCategoryGap": "20%",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "seriesId": 8586725,
#             "markPoint": {
#                 "data": []
#             },
#             "type": "bar",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "name": "Minimum",
#                         "type": "min"
#                     },
#                     {
#                         "name": "Maximum",
#                         "type": "max"
#                     }
#                 ],
#                 "symbolSize": 10
#             }
#         }
#     ],
#     "series_id": 8586725,
#     "toolbox": {
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "xAxis": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "inverse": false,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": false
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "type": "category",
#             "axisLabel": {
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "margin": 8
#             },
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "orient": "horizontal"
#         }
#     ],
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item"
#     }
# };
# myChart_d084813a53c64bdaa95f3573bdb48d55.setOption(option_d084813a53c64bdaa95f3573bdb48d55);
#
#     });
# </script>

# %%
bar = Bar("x 轴和 y 轴交换")
bar.add("商家A", attr, v1)
bar.add("商家B", attr, v2, is_convert=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="547e8e81d10541508576fb6a925fb203" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_547e8e81d10541508576fb6a925fb203 = echarts.init(document.getElementById('547e8e81d10541508576fb6a925fb203'), 'light', {renderer: 'canvas'});
#
# var option_547e8e81d10541508576fb6a925fb203 = {
#     "title": [
#         {
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "x \u8f74\u548c y \u8f74\u4ea4\u6362",
#             "top": "auto"
#         }
#     ],
#     "yAxis": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "inverse": false,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": true
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "type": "category",
#             "axisLabel": {
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "margin": 8
#             },
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "seriesId": 4249505,
#             "markPoint": {
#                 "data": []
#             },
#             "type": "bar",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markLine": {
#                 "data": []
#             }
#         },
#         {
#             "barCategoryGap": "20%",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "seriesId": 4249505,
#             "markPoint": {
#                 "data": []
#             },
#             "type": "bar",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markLine": {
#                 "data": []
#             }
#         }
#     ],
#     "series_id": 4249505,
#     "toolbox": {
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": false
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "type": "value",
#             "axisLabel": {
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "margin": 8
#             },
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "orient": "horizontal"
#         }
#     ],
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item"
#     }
# };
# myChart_547e8e81d10541508576fb6a925fb203.setOption(option_547e8e81d10541508576fb6a925fb203);
#
#     });
# </script>

# %%
from pyecharts import Bar, Timeline

from random import randint

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
bar_1 = Bar("2012 年销量", "数据纯属虚构")
bar_1.add("春季", attr, [randint(10, 100) for _ in range(6)])
bar_1.add("夏季", attr, [randint(10, 100) for _ in range(6)])
bar_1.add("秋季", attr, [randint(10, 100) for _ in range(6)])
bar_1.add("冬季", attr, [randint(10, 100) for _ in range(6)])

bar_2 = Bar("2013 年销量", "数据纯属虚构")
bar_2.add("春季", attr, [randint(10, 100) for _ in range(6)])
bar_2.add("夏季", attr, [randint(10, 100) for _ in range(6)])
bar_2.add("秋季", attr, [randint(10, 100) for _ in range(6)])
bar_2.add("冬季", attr, [randint(10, 100) for _ in range(6)])

bar_3 = Bar("2014 年销量", "数据纯属虚构")
bar_3.add("春季", attr, [randint(10, 100) for _ in range(6)])
bar_3.add("夏季", attr, [randint(10, 100) for _ in range(6)])
bar_3.add("秋季", attr, [randint(10, 100) for _ in range(6)])
bar_3.add("冬季", attr, [randint(10, 100) for _ in range(6)])

bar_4 = Bar("2015 年销量", "数据纯属虚构")
bar_4.add("春季", attr, [randint(10, 100) for _ in range(6)])
bar_4.add("夏季", attr, [randint(10, 100) for _ in range(6)])
bar_4.add("秋季", attr, [randint(10, 100) for _ in range(6)])
bar_4.add("冬季", attr, [randint(10, 100) for _ in range(6)])

bar_5 = Bar("2016 年销量", "数据纯属虚构")
bar_5.add("春季", attr, [randint(10, 100) for _ in range(6)])
bar_5.add("夏季", attr, [randint(10, 100) for _ in range(6)])
bar_5.add("秋季", attr, [randint(10, 100) for _ in range(6)])
bar_5.add("冬季", attr, [randint(10, 100) for _ in range(6)], is_legend_show=True)

timeline = Timeline(is_auto_play=True, timeline_bottom=0)
timeline.add(bar_1, '2012 年')
timeline.add(bar_2, '2013 年')
timeline.add(bar_3, '2014 年')
timeline.add(bar_4, '2015 年')
timeline.add(bar_5, '2016 年')

timeline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="411eef1b72db45219470978ad1558856" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_411eef1b72db45219470978ad1558856 = echarts.init(document.getElementById('411eef1b72db45219470978ad1558856'), 'light', {renderer: 'canvas'});
#
# var option_411eef1b72db45219470978ad1558856 = {
#     "baseOption": {
#         "yAxis": [
#             {
#                 "inverse": false,
#                 "boundaryGap": true,
#                 "splitLine": {
#                     "show": true
#                 },
#                 "nameLocation": "middle",
#                 "show": true,
#                 "type": "value",
#                 "axisLabel": {
#                     "rotate": 0,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "interval": "auto",
#                     "formatter": "{value} ",
#                     "margin": 8
#                 },
#                 "nameGap": 25,
#                 "axisTick": {
#                     "alignWithLabel": false
#                 },
#                 "nameTextStyle": {
#                     "fontSize": 14
#                 }
#             }
#         ],
#         "series": [],
#         "timeline": {
#             "symbol": "emptyCircle",
#             "top": "auto",
#             "show": true,
#             "data": [
#                 "2012 \u5e74",
#                 "2013 \u5e74",
#                 "2014 \u5e74",
#                 "2015 \u5e74",
#                 "2016 \u5e74"
#             ],
#             "symbolSize": 10,
#             "playInterval": 2000,
#             "axisType": "category",
#             "loop": true,
#             "autoPlay": true,
#             "right": "auto",
#             "left": "auto",
#             "rewind": false,
#             "bottom": 0
#         },
#         "xAxis": [
#             {
#                 "data": [
#                     "\u886c\u886b",
#                     "\u7f8a\u6bdb\u886b",
#                     "\u96ea\u7eba\u886b",
#                     "\u88e4\u5b50",
#                     "\u9ad8\u8ddf\u978b",
#                     "\u889c\u5b50"
#                 ],
#                 "inverse": false,
#                 "boundaryGap": true,
#                 "splitLine": {
#                     "show": false
#                 },
#                 "nameLocation": "middle",
#                 "show": true,
#                 "type": "category",
#                 "axisLabel": {
#                     "rotate": 0,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "interval": "auto",
#                     "margin": 8
#                 },
#                 "nameGap": 25,
#                 "axisTick": {
#                     "alignWithLabel": false
#                 },
#                 "nameTextStyle": {
#                     "fontSize": 14
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597",
#                 "#f6f5ec"
#             ],
#             "series": [
#                 {
#                     "barCategoryGap": "20%",
#                     "name": "\u6625\u5b63",
#                     "data": [
#                         42,
#                         55,
#                         58,
#                         87,
#                         94,
#                         80
#                     ],
#                     "seriesId": 4089098,
#                     "markPoint": {
#                         "data": []
#                     },
#                     "type": "bar",
#                     "label": {
#                         "normal": {
#                             "show": false,
#                             "textStyle": {
#                                 "fontSize": 12
#                             },
#                             "position": "top"
#                         },
#                         "emphasis": {
#                             "show": true,
#                             "textStyle": {
#                                 "fontSize": 12
#                             }
#                         }
#                     },
#                     "markLine": {
#                         "data": []
#                     }
#                 },
#                 {
#                     "barCategoryGap": "20%",
#                     "name": "\u590f\u5b63",
#                     "data": [
#                         98,
#                         37,
#                         60,
#                         47,
#                         34,
#                         63
#                     ],
#                     "seriesId": 4089098,
#                     "markPoint": {
#                         "data": []
#                     },
#                     "type": "bar",
#                     "label": {
#                         "normal": {
#                             "show": false,
#                             "textStyle": {
#                                 "fontSize": 12
#                             },
#                             "position": "top"
#                         },
#                         "emphasis": {
#                             "show": true,
#                             "textStyle": {
#                                 "fontSize": 12
#                             }
#                         }
#                     },
#                     "markLine": {
#                         "data": []
#                     }
#                 },
#                 {
#                     "barCategoryGap": "20%",
#                     "name": "\u79cb\u5b63",
#                     "data": [
#                         39,
#                         58,
#                         32,
#                         29,
#                         96,
#                         20
#                     ],
#                     "seriesId": 4089098,
#                     "markPoint": {
#                         "data": []
#                     },
#                     "type": "bar",
#                     "label": {
#                         "normal": {
#                             "show": false,
#                             "textStyle": {
#                                 "fontSize": 12
#                             },
#                             "position": "top"
#                         },
#                         "emphasis": {
#                             "show": true,
#                             "textStyle": {
#                                 "fontSize": 12
#                             }
#                         }
#                     },
#                     "markLine": {
#                         "data": []
#                     }
#                 },
#                 {
#                     "barCategoryGap": "20%",
#                     "name": "\u51ac\u5b63",
#                     "data": [
#                         87,
#                         38,
#                         70,
#                         90,
#                         33,
#                         14
#                     ],
#                     "seriesId": 4089098,
#                     "markPoint": {
#                         "data": []
#                     },
#                     "type": "bar",
#                     "label": {
#                         "normal": {
#                             "show": false,
#                             "textStyle": {
#                                 "fontSize": 12
#                             },

# %%
from pyecharts import WordCloud

name = ['Sam S Club', 'Macys', 'Amy Schumer', 'Jurassic World', 'Charter Communications',
        'Chick Fil A', 'Planet Fitness', 'Pitch Perfect', 'Express', 'Home', 'Johnny Depp',
        'Lena Dunham', 'Lewis Hamilton', 'KXAN', 'Mary Ellen Mark', 'Farrah Abraham',
        'Rita Ora', 'Serena Williams', 'NCAA baseball tournament', 'Point Break']
value = [10000, 6181, 4386, 4055, 2467, 2244, 1898, 1484, 1112, 965, 847, 582, 555,
         550, 462, 366, 360, 282, 273, 265]
wordcloud = WordCloud(width=1300, height=620)
wordcloud.add("", name, value, word_size_range=[20, 100])

wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="05b124aec4924cbb92ad7b913771a236" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_05b124aec4924cbb92ad7b913771a236 = echarts.init(document.getElementById('05b124aec4924cbb92ad7b913771a236'), 'light', {renderer: 'canvas'});
#
# var option_05b124aec4924cbb92ad7b913771a236 = {
#     "title": [
#         {
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item"
#     },
#     "series_id": 8431643,
#     "series": [
#         {
#             "girdSize": 20,
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,90,138)"
#                         }
#                     },
#                     "value": 10000
#                 },
#                 {
#                     "name": "Macys",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,141,59)"
#                         }
#                     },
#                     "value": 6181
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,31,37)"
#                         }
#                     },
#                     "value": 4386
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,59,25)"
#                         }
#                     },
#                     "value": 4055
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,114,8)"
#                         }
#                     },
#                     "value": 2467
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,66,106)"
#                         }
#                     },
#                     "value": 2244
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,50,91)"
#                         }
#                     },
#                     "value": 1898
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,113,39)"
#                         }
#                     },
#                     "value": 1484
#                 },
#                 {
#                     "name": "Express",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,135,156)"
#                         }
#                     },
#                     "value": 1112
#                 },
#                 {
#                     "name": "Home",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,41,118)"
#                         }
#                     },
#                     "value": 965
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,10,119)"
#                         }
#                     },
#                     "value": 847
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,83,24)"
#                         }
#                     },
#                     "value": 582
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,117,152)"
#                         }
#                     },
#                     "value": 555
#                 },
#                 {
#                     "name": "KXAN",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,155,18)"
#                         }
#                     },
#                     "value": 550
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,133,116)"
#                         }
#                     },
#                     "value": 462
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,65,139)"
#                         }
#                     },
#                     "value": 366
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,24,148)"
#                         }
#                     },
#                     "value": 360
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,51,25)"
#                         }
#                     },
#                     "value": 282
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,30,156)"
#                         }
#                     },
#                     "value": 273
#                 },
#                 {
#                     "name": "Point Break",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,37,23)"
#                         }
#                     },
#                     "value": 265
#                 }
#             ],
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "rotationStep": 45,
#             "shape": "circle",
#             "type": "wordCloud",
#             "rotationRange": [
#                 -90,
#                 90
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "textStyle": {
#                 "fontSize": 12
#             },

# %%
from pyecharts import Polar

import random
data = [(i, random.randint(1, 100)) for i in range(101)]
polar = Polar("极坐标系-散点图示例")
polar.add("", data, boundary_gap=False, type='scatter', is_splitline_show=False,
          area_color=None, is_axisline_show=True)

polar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="542d3d5958d743ca8b497def8bed284e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_542d3d5958d743ca8b497def8bed284e = echarts.init(document.getElementById('542d3d5958d743ca8b497def8bed284e'), 'light', {renderer: 'canvas'});
#
# var option_542d3d5958d743ca8b497def8bed284e = {
#     "title": [
#         {
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u6781\u5750\u6807\u7cfb-\u6563\u70b9\u56fe\u793a\u4f8b",
#             "top": "auto"
#         }
#     ],
#     "angleAxis": {
#         "startAngle": 90,
#         "boundaryGap": false,
#         "show": true,
#         "axisLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "curveness": 0,
#                     "width": 1,
#                     "opacity": 1,
#                     "type": "solid"
#                 }
#             }
#         },
#         "splitLine": {
#             "show": false,
#             "lineStyle": {
#                 "normal": {
#                     "curveness": 0,
#                     "width": 1,
#                     "opacity": 1,
#                     "type": "solid"
#                 }
#             }
#         },
#         "type": "category",
#         "clockwise": true
#     },
#     "radiusAxis": {
#         "axisLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "curveness": 0,
#                     "width": 1,
#                     "opacity": 1,
#                     "type": "solid"
#                 }
#             }
#         },
#         "show": true,
#         "type": "category",
#         "z": 50,
#         "axisLabel": {
#             "rotate": 0
#         }
#     },
#     "polar": {},
#     "series": [
#         {
#             "data": [
#                 [
#                     0,
#                     22
#                 ],
#                 [
#                     1,
#                     88
#                 ],
#                 [
#                     2,
#                     92
#                 ],
#                 [
#                     3,
#                     23
#                 ],
#                 [
#                     4,
#                     48
#                 ],
#                 [
#                     5,
#                     24
#                 ],
#                 [
#                     6,
#                     20
#                 ],
#                 [
#                     7,
#                     36
#                 ],
#                 [
#                     8,
#                     89
#                 ],
#                 [
#                     9,
#                     69
#                 ],
#                 [
#                     10,
#                     3
#                 ],
#                 [
#                     11,
#                     90
#                 ],
#                 [
#                     12,
#                     19
#                 ],
#                 [
#                     13,
#                     97
#                 ],
#                 [
#                     14,
#                     37
#                 ],
#                 [
#                     15,
#                     57
#                 ],
#                 [
#                     16,
#                     80
#                 ],
#                 [
#                     17,
#                     2
#                 ],
#                 [
#                     18,
#                     20
#                 ],
#                 [
#                     19,
#                     19
#                 ],
#                 [
#                     20,
#                     43
#                 ],
#                 [
#                     21,
#                     89
#                 ],
#                 [
#                     22,
#                     22
#                 ],
#                 [
#                     23,
#                     52
#                 ],
#                 [
#                     24,
#                     56
#                 ],
#                 [
#                     25,
#                     48
#                 ],
#                 [
#                     26,
#                     56
#                 ],
#                 [
#                     27,
#                     10
#                 ],
#                 [
#                     28,
#                     78
#                 ],
#                 [
#                     29,
#                     24
#                 ],
#                 [
#                     30,
#                     18
#                 ],
#                 [
#                     31,
#                     24
#                 ],
#                 [
#                     32,
#                     62
#                 ],
#                 [
#                     33,
#                     31
#                 ],
#                 [
#                     34,
#                     16
#                 ],
#                 [
#                     35,
#                     15
#                 ],
#                 [
#                     36,
#                     32
#                 ],
#                 [
#                     37,
#                     39
#                 ],
#                 [
#                     38,
#                     67
#                 ],
#                 [
#                     39,
#                     41
#                 ],
#                 [
#                     40,
#                     75
#                 ],
#                 [
#                     41,
#                     52
#                 ],
#                 [
#                     42,
#                     76
#                 ],
#                 [
#                     43,
#                     20
#                 ],
#                 [
#                     44,
#                     45
#                 ],
#                 [
#                     45,
#                     86
#                 ],
#                 [
#                     46,
#                     38
#                 ],
#                 [
#                     47,
#                     76
#                 ],
#                 [
#                     48,
#                     54
#                 ],
#                 [
#                     49,
#                     6
#                 ],
#                 [
#                     50,
#                     14
#                 ],
#                 [
#                     51,
#                     7
#                 ],
#                 [
#                     52,
#                     72
#                 ],
#                 [
#                     53,
#                     2
#                 ],
#                 [
#                     54,
#                     67
#                 ],
#                 [
#                     55,
#                     32
#                 ],
#                 [
#                     56,
#                     11
#                 ],
#                 [
#                     57,
#                     65
#                 ],
#                 [
#                     58,
#                     26
#                 ],
#                 [
#                     59,
#                     25
#                 ],
#                 [
#                     60,
#                     33
#                 ],
#                 [
#                     61,
#                     59
#                 ],
#                 [
#                     62,
#                     48
#                 ],
#                 [
#                     63,
#                     18
#                 ],
#                 [
#                     64,
#                     96
#                 ],
#                 [
#                     65,
#                     18
#                 ],
#                 [
#                     66,
#                     17
#                 ],
#                 [
#                     67,
#                     39
#                 ],
#                 [
#                     68,
#                     96
#                 ],
#                 [
#                     69,
#                     32
#                 ],
#                 [
#                     70,
#                     58
#                 ],

# %%
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'echartsgl': '/nbextensions/echarts/echarts-gl.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="63f89229a740453c86a10b9d7c0d0906" style="width:800px;height:400px;"></div>
#     <div id="3f6b45b7a1834c1eb6cd0e0eb6f52586" style="width:800px;height:400px;"></div>
#     <div id="f2d7f0c1803e454c8bfdc02fa9790d85" style="width:1200px;height:600px;"></div>
#     <div id="5ed6f68e9b5e4e5fa668d77a56528278" style="width:1200px;height:600px;"></div>
#     <div id="4a66869edec54db4844175af68f9686f" style="width:800px;height:400px;"></div>
#     <div id="7215a0f84de140d2b033c6c840a4d0c4" style="width:1200px;height:600px;"></div>
#     <div id="95ffbc01522b446bbcb79b8678851753" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'echartsgl', 'china', 'liquidfill', '广东', 'wordcloud'], function(echarts) {
#
# var myChart_63f89229a740453c86a10b9d7c0d0906 = echarts.init(document.getElementById('63f89229a740453c86a10b9d7c0d0906'), 'light', {renderer: 'canvas'});
#
# var option_63f89229a740453c86a10b9d7c0d0906 = {
#     "toolbox": {
#         "top": "center",
#         "feature": {
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "left": "95%"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "type": "category",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "title": [
#         {
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "series": [
#         {
#             "name": "\u5546\u5bb6A",
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 9530,
#             "stack": "stack_9530",
#             "type": "bar",
#             "barCategoryGap": "20%",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "name": "\u5546\u5bb6B",
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 9530,
#             "stack": "stack_9530",
#             "type": "bar",
#             "barCategoryGap": "20%",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 10,
#                 25,
#                 8,
#                 60,
#                 20,
#                 80
#             ],
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "legend": [
#         {
#             "top": "top",
#             "show": true,
#             "selectedMode": "multiple",
#             "left": "center",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "type": "value",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series_id": 9530
# };
# myChart_63f89229a740453c86a10b9d7c0d0906.setOption(option_63f89229a740453c86a10b9d7c0d0906);
#
#
# var myChart_3f6b45b7a1834c1eb6cd0e0eb6f52586 = echarts.init(document.getElementById('3f6b45b7a1834c1eb6cd0e0eb6f52586'), 'light', {renderer: 'canvas'});
#
# var option_3f6b45b7a1834c1eb6cd0e0eb6f52586 = {
#     "toolbox": {
#         "top": "center",
#         "feature": {
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "left": "95%"
#     },
#     "legend": [
#         {
#             "top": "top",
#             "show": true,
#             "selectedMode": "multiple",
#             "left": "center",
#             "data": [
#                 ""
#             ],
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "show": true,
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
